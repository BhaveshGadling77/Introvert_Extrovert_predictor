# %%
import pandas as pd
obj = pd.read_csv('./data/train.csv')
print(obj)
obj.plot()
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# ...

# %% [markdown]
# ## Key data structures
# * Series 1D
# * Dataframe 2D

# %%
s = pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])
print(s)

# %%
df = pd.DataFrame({"names" : ["Bhavesh", "Sangram", "Anmol"], "marks": [100, 90, 9]})
df

# %%
df = pd.read_csv('./data/test.csv')
df.plot()
# print(df.head())
# print(df.tail())
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('./data/test.csv')
#       2 df.plot()
#       3 # print(df.head())
#       4 # print(df.tail())
#
# NameError: name 'pd' is not defined

# %%
df.info()

# %% [markdown]
# ## Data Selection

# %%
df[["id", "Time_spent_Alone"]]
# Out:
#          id  Time_spent_Alone
# 0     18524               3.0
# 1     18525               NaN
# 2     18526               3.0
# 3     18527               3.0
# 4     18528               9.0
# ...     ...               ...
# 6170  24694               3.0
# 6171  24695               8.0
# 6172  24696               2.0
# 6173  24697               3.0
# 6174  24698               NaN
#
# [6175 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# id                           18524
# Time_spent_Alone               3.0
# Stage_fear                      No
# Social_event_attendance        7.0
# Going_outside                  4.0
# Drained_after_socializing       No
# Friends_circle_size            6.0
# Post_frequency                 NaN
# Name: 0, dtype: object

# %%
df.head()
# Out:
#       id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0  18524               3.0         No                      7.0            4.0
# 1  18525               NaN        Yes                      0.0            0.0
# 2  18526               3.0         No                      5.0            6.0
# 3  18527               3.0         No                      4.0            4.0
# 4  18528               9.0        Yes                      1.0            2.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency
# 0                        No                  6.0             NaN
# 1                       Yes                  5.0             1.0
# 2                        No                 15.0             9.0
# 3                        No                  5.0             6.0
# 4                       Yes                  1.0             1.0

# %%
df.dropna()

# %%
df.fillna(0)
# Out:
#          id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0     18524               3.0         No                      7.0
# 1     18525               0.0        Yes                      0.0
# 2     18526               3.0         No                      5.0
# 3     18527               3.0         No                      4.0
# 4     18528               9.0        Yes                      1.0
# ...     ...               ...        ...                      ...
# 6170  24694               3.0         No                      5.0
# 6171  24695               8.0        Yes                      2.0
# 6172  24696               2.0         No                      4.0
# 6173  24697               3.0         No                      4.0
# 6174  24698               0.0        Yes                      1.0
#
#       Going_outside Drained_after_socializing  Friends_circle_size  \
# 0               4.0                        No                  6.0
# ...

# %%
df.rename(columns={"Id", })
